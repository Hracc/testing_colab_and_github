# %% [markdown]
# <a href="https://colab.research.google.com/github/Hracc/testing_colab_and_github/blob/main/main_file_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
# Out:
# Hello
